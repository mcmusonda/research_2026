# %% [markdown]
# # 1. Setup & Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV
df = pd.read_csv('results/lusaka_times_classified_edited.csv')

# %%
# Preview data
df.head()
# Out:
#                           file_name  article_index  article_id  \
# 0  lusaka_times_full_articles3.json              1      236031
# 1  lusaka_times_full_articles3.json              2      236027
# 2  lusaka_times_full_articles3.json              3      236017
# 3  lusaka_times_full_articles3.json              4      236011
# 4  lusaka_times_full_articles3.json              5      235987
#
#                                                title       date_published  \
# 0  The $10 Billion Energy Scandal: BBC Africa Eye...  2019-06-16T07:21:10
# 1            Today’s Message: Living With Enthusiasm  2019-06-16T07:07:13
# 2  Zambian President, Edgar Chagwa Lungu, says we...  2019-06-16T07:03:35
# 3             Luapula man defiles his 3 day old baby  2019-06-16T06:48:14
# 4        Augustine Mulenga: Zambia ready for Morocco  2019-06-15T21:30:51
#
#   author        source                                         source_url  \
# 0     12  lusaka times  https://www.lusakatimes.com/2019/06/16/the-10-...
# 1     12  lusaka times  https://www.lusakatimes.com/2019/06/16/todays-...
# 2     12  lusaka times  https://www.lusakatimes.com/2019/06/16/zambian...
# 3     12  lusaka times  https://www.lusakatimes.com/2019/06/16/luapula...
# 4      3  lusaka times  https://www.lusakatimes.com/2019/06/15/augusti...
#
#   classification    raw_model_response Unnamed: 10
# 0             no  not research related         NaN
# 1             no  not research related         NaN
# 2             no  not research related         NaN
# 3             no  not research related         NaN
# 4             no  not research related         NaN

# %%
df.columns
# Out:
# Index(['file_name', 'article_index', 'article_id', 'title', 'date_published',
#        'author', 'source', 'source_url', 'classification',
#        'raw_model_response', 'Unnamed: 10'],
#       dtype='object')

# %% [markdown]
# # 2. Data Cleaning
# Ensure the classification is consistent

# %%
# Standardize classification(yes/N0)
df['classification'] = df['classification'].str.strip().str.upper()

# Convert date
df['date_published'] = pd.to_datetime(df['date_published'], errors='coerce')

# Extract year
df['year'] = df['date_published'].dt.year

# %% [markdown]
# # 3. Frequency of Research-Based Articles
# ## Overall frequency

# %%
freq = df['classification'].value_counts()
print(freq)
# Out:
# classification
# NO     1247
# YES      92
# Name: count, dtype: int64

# %%
# Percentage
percentage = df['classification'].value_counts(normalize=True) * 100
print(percentage)
# Out:
# classification
# NO     93.129201
# YES     6.870799
# Name: proportion, dtype: float64

# %% [markdown]
# ## Visualization

# %%
freq.plot(kind='bar', title='Research vs Non-Research Articles')
plt.show()

# %% [markdown]
# # 4. Trend Over the Years

# %%
trend = df.groupby(['year', 'classification']).size().unstack(fill_value=0)

print(trend)
# Out:
# classification    NO  YES
# year
# 2019.0          1244   92

# %% [markdown]
# ## Plot trend

# %%
trend.plot(marker='o', title='Trend of Research-Based Articles Over Time')
plt.ylabel('Number of of Articles')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Percentage trend

# %%
trend_percent = trend.div(trend.sum(axis=1), axis=0)* 100

trend_percent.plot(marker='o', title='Percentage of Research-Based Articles Over Time')
plt.ylabel('Percentage (%)')
plt.show()

# %% [markdown]
# # 5. Insights by Media House

# %%
by_source = df.groupby(['source', 'classification']).size().unstack(fill_value=0)
print(by_source)
# Out:
# classification    NO  YES
# source
# lusaka times    1247   92

# %%
df.columns.tolist()
# Out:
# ['file_name',
#  'article_index',
#  'article_id',
#  'title',
#  'date_published',
#  'author',
#  'source',
#  'source_url',
#  'classification',
#  'raw_model_response',
#  'Unnamed: 10',
#  'year']

# %% [markdown]
# ## Percentage per source

# %%
by_source_percent = by_source.div(by_source.sum(axis=1), axis=0) * 100

print(by_source_percent)
# Out:
# classification         NO       YES
# source
# lusaka times    93.129201  6.870799

# %% [markdown]
# # 6. Monthly Trends

# %%
df['month'] = df['date_published'].dt.to_period('M')

monthly_trend = df.groupby(['month', 'classification']).size().unstack(fill_value=0)

monthly_trend.plot(figsize=(12,6), title='Monthly Trend of Articles')
plt.show()

# %% [markdown]
# # 7. Additional Insights

# %%
from collections import Counter
import re

research_articles = df[df['classification'] == 'YES']

text = " " . join(research_articles['title'].dropna())

words = re.findall(r'\w+', text.lower())
common_words = Counter(words).most_common(20)

print(common_words)
# Out:
# [('the', 31), ('to', 28), ('of', 28), ('in', 24), ('zambia', 23), ('and', 17), ('for', 14), ('s', 11), ('a', 11), ('zambian', 10), ('africa', 8), ('is', 7), ('from', 7), ('on', 7), ('at', 6), ('with', 6), ('by', 5), ('development', 5), ('national', 5), ('government', 5)]
